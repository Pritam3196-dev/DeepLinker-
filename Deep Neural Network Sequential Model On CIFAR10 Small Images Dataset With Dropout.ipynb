# %% [markdown]
# ## Deep Neural Network Sequential Model On CIFAR10 Small Images Dataset

# %% [markdown]
# #### About the Dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Data Dictionary :

# %% [markdown]
# #### The classes are :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Import basic packages

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense , BatchNormalization , Flatten , Dropout
from keras import Sequential
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import Inbuilt Dataset from keras

# %%
(x_train , y_train) , (x_test , y_test) = keras.datasets.cifar10.load_data()

# %%
print(x_train.shape , y_train.shape)
print(x_test.shape , y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# #### Insights : Total images are 60000. from 60000 images  , 50000 images are for training model and 10000 images for testing model

# %% [markdown]
# #### We will check how digits images look like

# %% [markdown]
# ###### Import visualization library

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x_train[0])
plt.show()

# %%
plt.imshow(x_train[1000])
plt.show()

# %%
plt.imshow(x_train[10000])
plt.show()

# %%
plt.imshow(x_train[49999])
plt.show()

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# #### In image dataset , we always doing feature scaling by normalization only.

# %% [markdown]
# ##### Image exist between 0 to 255 . If we divide 0/255 then it became 0 and 255/255 it became 1 only. after this range exist between 0 to 1 only. i.e. normalization

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# #### Insights : Data get scaled between 0 to 1 only.

# %% [markdown]
# #### Visualization plot of multiple images of training data

# %%
plt.figure(figsize = (25 ,10))
for image in range(50):
    
    plt.subplot(5 , 10 , image + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[image])
    plt.xlabel(y_train[image])
    
plt.show()

# %% [markdown]
# #### Visulization of multiple images of testing

# %%
plt.figure(figsize = (25 , 10))
for image in range(50):
    
    plt.subplot(5 , 10 , image + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[image])
    plt.xlabel(y_train[image])
plt.show()

# %% [markdown]
# ### Building Multilayer Perceptron Model or Deep Neural Network Model

# %%
DNN = Sequential()

# %% [markdown]
# #### This data is 3 dimensional data . so we need to convert 3 dimensional data into 1 dimensional data . by Faltten , we will do this.

# %% [markdown]
# ##### We just need to give input shape

# %%
DNN.add(Flatten(input_shape = (32 , 32, 3)))

# %% [markdown]
# #### 1st hidden layer

# %%
DNN.add(Dense(units = 64 ,  activation = 'relu' , ))

# %% [markdown]
# #### We can use Batchnormalization or Dropout here after each hidden layer

# %%
#DNN.add(BatchNormalization())
DNN.add(Dropout(0.25))

# %% [markdown]
# #### 2nd hidden layer

# %%
DNN.add(Dense(units = 32 , activation = 'relu'))

# %%
#DNN.add(BatchNormalization())
DNN.add(Dropout(0.30))

# %% [markdown]
# #### 3rd hidden layer

# %%
DNN.add(Dense(units = 16 , activation = 'relu'))

# %%
#DNN.add(BatchNormalization())
DNN.add(Dropout(0.50))

# %% [markdown]
# #### Output Layer

# %%
DNN.add(Dense(units = 10 , activation = 'softmax'))

# %% [markdown]
# ##### Insights : In target variable , it contains 10 classes

# %% [markdown]
# #### Oprational Parameters of sequential architecture

# %%
DNN.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         196,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 199,450 (779.10 KB)
#  Trainable params: 199,450 (779.10 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Data after 1D is 3072   i.e.(32 * 32 * 3)
#
# #### Operational Parameters are (3072 * 64 + 64) + (64 * 32 + 32) + (32 * 16 + 16) + (16 * 10 + 10) = 199450

# %% [markdown]
# #### Compile the model

# %%
DNN.compile(optimizer = 'adam' , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])

# %% [markdown]
# #### Fit the model

# %%
history = DNN.fit(x_train , y_train , validation_data = (x_test , y_test) , epochs = 100 ,batch_size = 32)
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.1012 - loss: 2.3163 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.0996 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1009 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.0968 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.1030 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.0996 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.1009 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1005 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.0989 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.1006 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.1013 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.1006 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.0987 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.0988 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.1019 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.0968 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.0968 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.0990 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0991 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.0982 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0969 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0998 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0992 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.1038 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1026 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0996 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 28/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.0998 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 29/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0973 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 30/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0998 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 31/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 32/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 8ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 33/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.0968 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 34/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.0997 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 35/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.0965 - loss: 2.3028 - val_accuracy: 0.1001 - val_loss: 2.3026
# Epoch 36/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.0999 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 37/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1013 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 38/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0978 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 39/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1020 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 40/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 41/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 42/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0981 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 43/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0991 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 44/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1035 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 45/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0991 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 46/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0953 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 47/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.0984 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 48/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - accuracy: 0.0994 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 49/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.0994 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 50/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.0978 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 51/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.0955 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 52/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.0991 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 53/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.0989 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 54/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0996 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 55/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0983 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 56/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 57/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.0967 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 58/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 51s 23ms/step - accuracy: 0.0992 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 59/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.0994 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 60/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.0991 - loss: 2.3028 - val_accuracy: 0.1001 - val_loss: 2.3026
# Epoch 61/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1006 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 62/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0998 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 63/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0985 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 64/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0971 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 65/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0986 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 66/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0983 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 67/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0983 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 68/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1028 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 69/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 70/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0998 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 71/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0981 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 72/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0982 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 73/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 74/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0966 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 75/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0980 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 76/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.1000 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 77/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.0973 - loss: 2.3028 - val_accuracy: 0.1001 - val_loss: 2.3027
# Epoch 78/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.0968 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 79/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0950 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 80/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0991 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 81/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.1006 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 82/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0993 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 83/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1011 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 84/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0980 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 85/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0957 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 86/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.0970 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 87/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.0974 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 88/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.0999 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 89/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.0991 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 90/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.0987 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.0983 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.0973 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.1012 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0973 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 97/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 98/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.0985 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 99/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.1004 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 100/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - accuracy: 0.1007 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026

# %% [markdown]
# #### Calulate Prediction Output

# %%
y_train_pred = DNN.predict(x_train)
y_test_pred = DNN.predict(x_test)
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# #### We calculate prediction output but this is softmax loss function . It give more than one possibility . we want consider that possibility as output which contains highest probability

# %%
y_train_pred = y_train_pred.reshape(-1 , 1)
y_test_pred  = y_test_pred.reshape(-1 , 1)

y_train_pred = y_train_pred.argmax(axis = 1)
y_test_pred = y_test_pred.argmax(axis = 1)

# %%
print(y_test_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %% [markdown]
# #### Performance Metrics

# %%
from sklearn.metrics import accuracy_score

# %%
# print('Training Accuracy (Accuracy) :' , accuracy_score(y_train , y_train_pred))

# print('Testing Accuracy (Val_accuracy) :' , accuracy_score(y_test , y_test_pred))

# %% [markdown]
# #### Visualization of Accuracies

# %%
plt.figure(figsize = (25 , 10))
plt.plot(history.history['accuracy'] ,color='orange', marker='o',
         linestyle='dashed',linewidth=1, markersize=5 )
plt.plot(history.history['val_accuracy'] ,color='magenta', marker='o',
         linestyle='dashed',linewidth=1, markersize=5 )
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# #### visualization of Loss

# %%
plt.figure(figsize = (25 , 10))
plt.plot(history.history['loss'] , color='orange', marker='o',
         linestyle='dashed',linewidth=1, markersize=5)
plt.plot(history.history['val_loss'] , color='magenta', marker='o',
         linestyle='dashed',linewidth=1, markersize=5)
plt.ylabel('Loss')
plt.show()
